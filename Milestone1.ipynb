# %%
import numpy as np
import pandas as pd

data = pd.read_csv('/Users/takonyabadza/Desktop/course-project-group_317/spi_global_rankings.csv')
data.head()
# Out:
#    rank                 name                    league    spi
# 0     1        Bayern Munich         German Bundesliga  94.37
# 1     2      Manchester City   Barclays Premier League  92.00
# 2     3  Paris Saint-Germain            French Ligue 1  90.08
# 3     4            Barcelona  Spanish Primera Division  89.66
# 4     5            Liverpool   Barclays Premier League  88.69

# %%
import pandas as pd
df = pd.read_csv("/Users/takonyabadza/Desktop/course-project-group_317/spiglobalrankings.csv")
df = df.drop([ 'league'], axis=1)
df = df.dropna()
df = df.reset_index()
df['weighted_scores']=df['off']*.25 + df['def']*.25 + df['spi']*.50 
df
# Out:
#      index  rank  prev_rank                 name   off   def    spi  \
# 0        0     1          1        Bayern Munich  3.51  0.43  93.96
# 1        1     2          2      Manchester City  2.86  0.24  92.84
# 2        2     3          3            Barcelona  3.01  0.50  90.16
# 3        3     4          5            Liverpool  2.79  0.46  88.95
# 4        4     5          4  Paris Saint-Germain  2.89  0.52  88.85
# ..     ...   ...        ...                  ...   ...   ...    ...
# 632    632   633        635           Scunthorpe  0.30  2.43   7.21
# 633    633   634        633       Harrogate Town  0.20  2.20   6.95
# 634    634   635        634    Loudoun United FC  0.34  2.65   6.51
# 635    635   636        636      Southend United  0.23  2.42   6.12
# 636    636   637        637   Bethlehem Steel FC  0.41  2.99   5.78
#
#      weighted_scores
# 0            47.9650
# 1            47.1950
# 2            45.9575
# 3            45.2875
# 4            45.2775
# ..               ...
# 632           4.2875
# 633           4.0750
# 634           4.0025
# 635           3.7225
# 636           3.7400
#
# [637 rows x 8 columns]

# %%
# Your Solution here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/Users/takonyabadza/Desktop/course-project-group_317/spiglobalrankings.csv")
df['weighted_scores']=df['off']*.25 + df['def']*.25 + df['spi']*.50 
sns.set_theme(style="dark", font_scale=1.5)
d= sns.pairplot(data=df, vars=('off', 'def', 'spi', 'weighted_scores'), corner=True)
d.fig.suptitle('Team strength distribution')
plt.show()

# %%
# Your Solution here
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/Users/takonyabadza/Desktop/course-project-group_317/spiglobalrankings.csv")
df['weighted_scores']=df['off']*.25 + df['def']*.25 + df['spi']*.50
df2 = df.groupby(by=['spi']).mean().sort_values(by=['def'], ascending=False)
sns.set_theme(style="dark", font_scale=1.5)
d = sns.boxplot(x='def', y='name', data=df)
d = sns.stripplot(x='def', y='name', data=df)
plt.title('Teams sorted by Defense')
d.set(xlabel='Defense', ylabel=None)
plt.show()

# %%
##What Team has had the Best Defense lately, contributed by looking at Team's Performance on Defending and their Soccer Power Index?##

##1. Borussia Dortmund
##2.Barcelona##
